# %%
fh = open('data/txt/03-931.txt')

for line in fh.readlines():
    if not line.isspace():
        if not line.strip().startswith('Alderson Reporting Company'):
            if not line.strip().startswith('1111 14th Street NW, Suite 400'):
                workLine = line.strip()
#                if workLine.find('C O N T E N T S') > -1:
#                    print workLine
                print workLine
# Out:
# 1                               IN THE SUPREME COURT OF THE UNITED STATES
# 2              - - - - - - - - - - - - - - - -X
# 3              FLORIDA,                                      :
# 4                               Petitioner                   :
# 5                      v.                                    :     No. 03-931
# 6              JOE ELTON NIXON.                              :
# 7              - - - - - - - - - - - - - - - -X
# 8                                                         Washington, D.C.
# 9                                                         Tuesday, November 2, 2004
# 10                               The   above-entitled         matter    came    on    for   oral
# 11              argument before the Supreme Court of the United States                         at
# 12              10:02 a.m.
# 13              APPEARANCES:
# 14              GEORGE S. LEMIEUX, ESQ., Deputy Attorney General,
# ...
